# %% [markdown]
# # 12_03 공통요인분석(CFA)

# %%
# 필요한 패키지 설치 및 임포트
# !pip install factor-analyzer
from sklearn.preprocessing import MinMaxScaler
from factor_analyzer import FactorAnalyzer
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
from factor_analyzer.factor_analyzer import calculate_kmo
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: factor-analyzer in /Users/adam/anaconda3/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: pandas in /Users/adam/anaconda3/lib/python3.10/site-packages (from factor-analyzer) (1.5.3)
# Requirement already satisfied: scipy in /Users/adam/anaconda3/lib/python3.10/site-packages (from factor-analyzer) (1.10.1)
# Requirement already satisfied: numpy in /Users/adam/anaconda3/lib/python3.10/site-packages (from factor-analyzer) (1.23.5)
# Requirement already satisfied: scikit-learn in /Users/adam/anaconda3/lib/python3.10/site-packages (from factor-analyzer) (1.2.1)
# Requirement already satisfied: pre-commit in /Users/adam/anaconda3/lib/python3.10/site-packages (from factor-analyzer) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/adam/anaconda3/lib/python3.10/site-packages (from pandas->factor-analyzer) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/adam/anaconda3/lib/python3.10/site-packages (from pandas->factor-analyzer) (2022.7)
# Requirement already satisfied: cfgv>=2.0.0 in /Users/adam/anaconda3/lib/python3.10/site-packages (from pre-commit->factor-analyzer) (3.3.1)
# Requirement already satisfied: identify>=1.0.0 in /Users/adam/anaconda3/lib/python3.10/site-packages (from pre-commit->factor-analyzer) (2.5.24)
# Requirement already satisfied: nodeenv>=0.11.1 in /Users/adam/anaconda3/lib/python3.10/site-packages (from pre-commit->factor-analyzer) (1.8.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/adam/anaconda3/lib/python3.10/site-packages (from pre-commit->factor-analyzer) (6.0)
# Requirement already satisfied: virtualenv>=20.10.0 in /Users/adam/anaconda3/lib/python3.10/site-packages (from pre-commit->factor-analyzer) (20.23.0)
# Requirement already satisfied: joblib>=1.1.1 in /Users/adam/anaconda3/lib/python3.10/site-packages (from scikit-learn->factor-analyzer) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/adam/anaconda3/lib/python3.10/site-packages (from scikit-learn->factor-analyzer) (2.2.0)
# Requirement already satisfied: setuptools in /Users/adam/anaconda3/lib/python3.10/site-packages (from nodeenv>=0.11.1->pre-commit->factor-analyzer) (65.6.3)
# Requirement already satisfied: six>=1.5 in /Users/adam/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->factor-analyzer) (1.16.0)
# Requirement already satisfied: distlib<1,>=0.3.6 in /Users/adam/anaconda3/lib/python3.10/site-packages (from virtualenv>=20.10.0->pre-commit->factor-analyzer) (0.3.6)
# Requirement already satisfied: filelock<4,>=3.11 in /Users/adam/anaconda3/lib/python3.10/site-packages (from virtualenv>=20.10.0->pre-commit->factor-analyzer) (3.12.0)
# Requirement already satisfied: platformdirs<4,>=3.2 in /Users/adam/anaconda3/lib/python3.10/site-packages (from virtualenv>=20.10.0->pre-commit->factor-analyzer) (3.5.1)

# %%
# 데이터 불러오기
df = pd.read_csv('/Users/adam/Data_Analytics/Python/Datasets/nba2021/nba2021_advanced.csv')

# 데이터 샘플 확인
df.head()
# Out:
#               Player Pos  Age   Tm   G   MP   PER    TS%   3PAr    FTr  ...  \
# 0   Precious Achiuwa  PF   21  MIA  28  408  15.1  0.599  0.000  0.541  ...
# 1       Jaylen Adams  PG   24  MIL   6   17  -6.9  0.125  0.250  0.000  ...
# 2       Steven Adams   C   27  NOP  27  760  15.9  0.592  0.006  0.397  ...
# 3        Bam Adebayo   C   23  MIA  26  873  22.7  0.641  0.015  0.469  ...
# 4  LaMarcus Aldridge   C   35  SAS  18  480  15.2  0.542  0.298  0.093  ...
#
#    TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM   BPM  VORP
# 0  16.1  19.7  0.3  0.6  0.9  0.101  -2.8  -0.2  -3.0  -0.1
# 1   0.0  19.7 -0.1  0.0 -0.1 -0.265 -15.6  -5.2 -20.9  -0.1
# 2  20.1  12.8  1.2  0.5  1.7  0.109  -0.1  -1.0  -1.1   0.2
# 3  16.2  24.6  2.3  1.3  3.6  0.196   2.9   2.0   4.9   1.5
# 4   6.4  22.3  0.2  0.5  0.7  0.075   0.3  -1.0  -0.7   0.2
#
# [5 rows x 26 columns]

# %%
# 변수 선택 및 데이터 스케일 정규화

# 요인 분석할 컬럼만 선택(문자형 변수 등 제거)
df1 = df.drop(['Player','Pos','Tm','Age'], axis='columns')

# 데이터 정규화 적용
MinMaxScaler = MinMaxScaler()
df_minmax = MinMaxScaler.fit_transform(df1)

# 컬럼명 결합
df_minmax = pd.DataFrame(data=df_minmax, columns=df1.columns)

df_minmax.head()
# Out:
#           G        MP       PER       TS%   3PAr       FTr      ORB%  \
# 0  0.931034  0.369427  0.703518  0.399333  0.000  0.202850  0.300000
# 1  0.172414  0.013649  0.427136  0.083333  0.250  0.000000  0.000000
# 2  0.896552  0.689718  0.713568  0.394667  0.006  0.148856  0.482857
# 3  0.862069  0.792539  0.798995  0.427333  0.015  0.175853  0.194286
# 4  0.586207  0.434941  0.704774  0.361333  0.298  0.034871  0.091429
#
#        DRB%      TRB%      AST%  ...   TOV%      USG%       OWS       DWS  \
# 0  0.365989  0.550000  0.143158  ...  0.161  0.450382  0.245902  0.318182
# 1  0.336414  0.335714  0.282105  ...  0.000  0.450382  0.180328  0.045455
# 2  0.332717  0.625000  0.212632  ...  0.201  0.274809  0.393443  0.272727
# 3  0.428835  0.550000  0.587368  ...  0.162  0.575064  0.573770  0.636364
# 4  0.258780  0.300000  0.240000  ...  0.064  0.516539  0.229508  0.272727
#
#          WS     WS/48      OBPM      DBPM       BPM      VORP
# 0  0.239437  0.836054  0.688192  0.552147  0.677419  0.146341
# 1  0.098592  0.587075  0.452030  0.245399  0.402458  0.146341
# 2  0.352113  0.841497  0.738007  0.503067  0.706605  0.219512
# 3  0.619718  0.900680  0.793358  0.687117  0.798771  0.536585
# 4  0.211268  0.818367  0.745387  0.503067  0.712750  0.219512
#
# [5 rows x 22 columns]

# %%
# 바틀렛(Bartlett)테스트
chi_square_value, p_value = calculate_bartlett_sphericity(df_minmax)

# 카이스퀘어, P-value 확인
chi_square_value, p_value
# Out:
# (20174.082695118635, 0.0)

# %%
# KMO 검정
kmo_all, kmo_test=calculate_kmo(df_minmax)
kmo_test
# Out:
# /Users/adam/anaconda3/lib/python3.10/site-packages/factor_analyzer/utils.py:244: UserWarning: The inverse of the variance-covariance matrix was calculated using the Moore-Penrose generalized matrix inversion, due to its determinant being at or very close to zero.
#   warnings.warn(
# 0.7017388419159669

# %%
# 전체 요인 적재값 확인
fa = FactorAnalyzer(n_factors=30, rotation=None)
fa.fit(df_minmax)
ev, v = fa.get_eigenvalues()

np.round_(ev,2)
# Out:
# array([7.91, 3.53, 2.25, 1.59, 1.45, 1.05, 0.86, 0.67, 0.59, 0.57, 0.45,
#        0.37, 0.24, 0.17, 0.11, 0.08, 0.07, 0.03, 0.01, 0.  , 0.  , 0.  ])

# %%
# 스크리 도표 시각화

plt.scatter(range(1, df_minmax.shape[1]+1), ev)
plt.plot(range(1, df_minmax.shape[1]+1), ev)
plt.title('Scree Plot')
plt.xlabel('Factors')
plt.ylabel('Eigenvalue')
plt.grid()
plt.show()

# %%
# 요인 수 선정 및 요인-변수 간 요인 적재 값 확인

fa = FactorAnalyzer(n_factors=4, rotation='varimax')
fa.fit(df_minmax)
factor_loadings = pd.DataFrame(fa.loadings_, index=df_minmax.columns)
factor_loadings
# Out:
#               0         1         2         3
# G      0.280363 -0.120974  0.823695  0.054468
# MP     0.235239 -0.114616  0.820694  0.349032
# PER    0.832268  0.305573  0.147761  0.411650
# TS%    0.746473  0.103235  0.151836  0.069871
# 3PAr  -0.015289 -0.593922  0.004644 -0.180311
# FTr    0.087057  0.356382 -0.173463  0.112161
# ORB%   0.042655  0.785599 -0.047214 -0.058840
# DRB%   0.105775  0.711622  0.131665 -0.009666
# TRB%   0.076869  0.971609  0.092116 -0.049174
# AST%   0.072484 -0.176681  0.082553  0.571263
# STL%   0.162854 -0.158276  0.167052 -0.010402
# BLK%   0.061263  0.615849 -0.000813 -0.131920
# TOV%  -0.512815  0.161094 -0.048920  0.040294
# USG%  -0.039402  0.024691  0.010200  0.644357
# OWS    0.335777  0.122376  0.422589  0.662219
# DWS    0.210791  0.157760  0.814380  0.264731
# WS     0.322705  0.156197  0.636343  0.627248
# WS/48  0.934784  0.202072  0.211533  0.114420
# OBPM   0.870437  0.050989  0.165258  0.382697
# DBPM   0.531773  0.201113  0.264126 -0.118064
# BPM    0.931222  0.110370  0.235261  0.249336
# VORP   0.292786  0.140378  0.367490  0.751926

# %%
# 변수 간 요인 적재 값 시각화

plt.figure(figsize=(6, 10))
sns.heatmap(abs(factor_loadings), cmap='PuBu', annot=True, fmt='.2f')
# Out:
# <Axes: >
